# %%
import torch
import torch.nn.functional as F

def soft_topk(s: torch.Tensor, k: int, tau1: float = 5e-2, tau2: float = 1e-2):
    # softmax 归一化
    s = F.softmax(s, dim=-1)

    # 差值矩阵
    diff = torch.unsqueeze(s, -1) - torch.unsqueeze(s, -2)

    # sigma
    sigma = torch.sigmoid(-diff / tau1)

    # row sum
    row_sum = sigma.sum(dim=-1) - 0.5

    # r_tilde
    r_tilde = 1.0 + row_sum

    # gating
    eps = 0.5
    a = torch.sigmoid((k + eps - r_tilde) / tau2)

    # final output
    a = a * s
    return a
z = torch.tensor([0.2, 1.3])  # 输入张量
k = 1

softz = soft_topk(z, k)          # 软 topk
softz= softz/softz.sum(-1,keepdim=True)

z=F.softmax(z, dim=-1)
topkz,_ = torch.topk(z, k)    # 正常的 topk
topkz= topkz/topkz.sum(-1,keepdim=True)  



print("topk:", topkz)
print("soft topk:", softz)
# Out:
# topk: tensor([1.])
# soft topk: tensor([6.4492e-23, 1.0000e+00])
